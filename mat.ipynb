# %%
plt.plot(x,y)

# %%
plt.xlabel("Day")          ## naming x  
plt.ylabel("Temprature")   ## naming y axis
plt.title("Weather")       ## seting title of chart   
### x & y axis , width , style 
plt.plot(x,y,color='red',linewidth=3,linestyle='dashdot')

# %%
## g+  green and points are star
plt.plot(x,y,"g*")

# %%
## markers def points  
plt.plot(x,y,'--',marker="*",markersize=10)

# %%
plt.plot(x,y,color='red',alpha=0.5)

# %%
x1=[-3,-2,-1,0,1,2,3,4]
y1=[9,4,1,0,1,4,9,16]

plt.xlabel("Numbers")
plt.ylabel("Squares")
plt.title("Square of Numbers")

plt.plot(x1,y1,color='blue',marker='+',markersize=10,linestyle="dotted")

# %% [markdown]
# **bar chart**

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,47]
avg_t=[45,48,48,46,40,42,41]

# %%
plt.xlabel("Days")
plt.ylabel("Temprature")
plt.title("Weather")

### ploting multiple lines on single graph

plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t)

# %% [markdown]
# *what these lines are???*

# %%
plt.xlabel("Days")
plt.ylabel("Temprature")
plt.title("Weather")

### ploting multiple lines on single graph

plt.plot(days,max_t, label="Max")
plt.plot(days,min_t, label="Min")
plt.plot(days,avg_t, label="Avg")

plt.legend(loc="lower left",shadow=True,fontsize='small')

plt.grid()

# %%
import numpy as np

# %%
company=["GOOGL","AMZN","MSFT","FB"]
revenue=[90,136,89,27]
profit=[40,100,70,20]

# %%
### array 0 1 2 3 position of company on x axis
xpos=np.arange(len(company))


plt.ylabel("Prices")
plt.xticks(xpos,company)   ### replace 0123 by  company names
plt.title("Stock prices")

plt.bar(xpos-0.1,revenue,label="Revenue",width=0.3)
plt.bar(xpos+0.1,profit,label="Profit",width=0.3)
plt.legend()

### same thing done in horizontal format ny barh function
### then yticks are used

# %% [markdown]
# **Histograms**

# %%
patients=[]
bloodsugar= [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

# %%
plt.hist(bloodsugar,bins=5,rwidth=0.90)
## relative width of bard  wrt to bins
# Out:
# (array([6., 1., 2., 2., 2.]),
#  array([ 77. ,  91.6, 106.2, 120.8, 135.4, 150. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(bloodsugar,bins=[80,100,150,180],rwidth=0.90,color="g",orientation='horizontal')
# for side by side histogrmg give array and color label array too
# Out:
# (array([6., 5., 1.]),
#  array([ 80., 100., 150., 180.]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# **pie chart**

# %%
exp_values=[7000,3000,1000,500,600,450]
exp_labels=["Home_rent","Food","Internet bill" ,"Car","Travel","Other"]

# %%
plt.pie(exp_values,labels=exp_labels,radius=1,autopct='%0.2f%%',shadow=True,explode=[0,0.2,0,0,0.1,0])
## autopct gives percentage of areas { 0.2 >> two decimals after percentage}
#plt.axis("equals")  # gives perfect circle
plt.show() ## removes arguments above pie 
# explode reoves pie by amount give in corresponding list position
